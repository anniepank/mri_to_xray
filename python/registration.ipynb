# %%
import SimpleITK

fixedImage = SimpleITK.ReadImage("cxr.nii")
movingImage = SimpleITK.ReadImage("output.nii")
resultImage = SimpleITK.ElastixImageFilter()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-37742d416d1c> in <module>
#       3 fixedImage = SimpleITK.ReadImage("cxr.nii")
#       4 movingImage = SimpleITK.ReadImage("output.nii")
# ----> 5 resultImage = SimpleITK.ElastixImageFilter()
#
# AttributeError: module 'SimpleITK' has no attribute 'ElastixImageFilter'

# %%
dir(SimpleITK)
# Out:
# ['Abs',
#  'AbsImageFilter',
#  'AbsImageFilter_swigregister',
#  'AbsoluteValueDifference',
#  'AbsoluteValueDifferenceImageFilter',
#  'AbsoluteValueDifferenceImageFilter_swigregister',
#  'Acos',
#  'AcosImageFilter',
#  'AcosImageFilter_swigregister',
#  'AdaptiveHistogramEqualization',
#  'AdaptiveHistogramEqualizationImageFilter',
#  'AdaptiveHistogramEqualizationImageFilter_swigregister',
#  'Add',
#  'AddImageFilter',
#  'AddImageFilter_swigregister',
#  'AdditiveGaussianNoise',
#  'AdditiveGaussianNoiseImageFilter',
#  'AdditiveGaussianNoiseImageFilter_swigregister',
#  'AffineTransform',
#  'AffineTransform_swigregister',
#  'AggregateLabelMap',
#  'AggregateLabelMapFilter',
#  'AggregateLabelMapFilter_swigregister',
#  'And',
#  'AndImageFilter',
#  'AndImageFilter_swigregister',
#  'AntiAliasBinary',
#  'AntiAliasBinaryImageFilter',
#  'AntiAliasBinaryImageFilter_swigregister',
#  'ApproximateSignedDistanceMap',
#  'ApproximateSignedDistanceMapImageFilter',
# ...
